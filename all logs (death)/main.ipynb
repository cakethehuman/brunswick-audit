# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# # We read the data first

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#                      name  kills        date
# 0              GGXDArusha     50  2025-02-12
# 1             Kangcheon24     54  2025-02-12
# 2    Indonesia_ofMalaysia     43  2025-02-12
# 3                 jgwen19     56  2025-02-12
# 4            mrflipsflapz     49  2025-02-12
# ..                    ...    ...         ...
# 324        infantry154111     14  2025-01-28
# 325            camper8903     45  2025-01-28
# 326      ChickenDonkeyDog     59  2025-01-28
# 327               pensmen     26  2025-01-28
# 328             Logiclist      8  2025-01-28
#
# [329 rows x 3 columns]

# %% [markdown]
# # Top 10 attandence all time

# %%
df["name"].value_counts().nlargest(10).plot(kind='bar',colormap='viridis')
plt.title("Attendance by Name")
plt.xlabel("Name")
plt.grid()
plt.ylabel("Attendance")
plt.show()

# %% [markdown]
# # avg attadance

# %%
round(df["name"].value_counts().mean())
# Out:
# 3

# %% [markdown]
# # Historigram for kills

# %%
plt.hist(df["kills"], bins=15, color='green', edgecolor='black')

plt.title("finding the average kills")
plt.plot()
plt.show()

# %%
avg_kills_everyone = df["kills"].mean()
print("The average kills for everyone is: ", round(avg_kills_everyone))
# Out:
# The average kills for everyone is:  44

# %% [markdown]
# # There top 5 kills

# %%
find_avg = df[df["name"] == "mrflipsflapz"]
#you can put anyname 
find_avg["kills"].mean()

number_sort = find_avg["kills"].sort_values(ascending=False)

plt.bar(find_avg.sort_values(ascending=False, by="kills")["date"], find_avg["kills"].sort_values(ascending=False), color='black')


        
plt.title(f"Kills by Date by {find_avg['name'].iloc[0]}")
plt.xticks(rotation=90)
plt.xlabel("Date")
plt.ylabel("Kills")
plt.show()

# %% [markdown]
# # There performance for the last 5 days

# %%
find_name = df[df["name"] == "Oscarchoyzy24"]
find_name
# Out:
#               name  kills        date
# 23   Oscarchoyzy24     61  2025-02-12
# 48   Oscarchoyzy24     18  2025-02-11
# 85   Oscarchoyzy24     83  2025-02-09
# 109  Oscarchoyzy24     83  2025-02-08
# 150  Oscarchoyzy24     19  2025-02-07
# 172  Oscarchoyzy24     81  2025-02-06
# 215  Oscarchoyzy24     87  2025-02-05
# 223  Oscarchoyzy24     75  2025-02-04
# 256  Oscarchoyzy24     72  2025-01-30

# %%
i = 0
kills_5_days = []
while i < 5:
    print(find_name["kills"].iloc[i])
    kills_5_days.append(find_name["kills"].iloc[i])
    i = i + 1
# Out:
# 61
# 18
# 83
# 83
# 19

# %%
plt.bar(find_name["date"].head(5), kills_5_days, color='black')
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# # Avg kills for the last 5 days

# %%
find_name["kills"].head(5).mean()
# Out:
# np.float64(52.8)
