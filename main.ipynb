# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# # We read the data first

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#                  name  kills        date
# 0             jgwen19     70  2025-02-09
# 1             Dawnftb     34  2025-02-09
# 2          Hparso1524     36  2025-02-09
# 3    MarionnJames2307     61  2025-02-09
# 4      chickenkampong     47  2025-02-09
# ..                ...    ...         ...
# 263    infantry154111     14  2025-01-28
# 264        camper8903     45  2025-01-28
# 265  ChickenDonkeyDog     59  2025-01-28
# 266           pensmen     26  2025-01-28
# 267         Logiclist      8  2025-01-28
#
# [268 rows x 3 columns]

# %% [markdown]
# # Top 10 attandence

# %%
df["name"].value_counts().nlargest(10).plot(kind='bar',colormap='viridis')
plt.title("Attendance by Name")
plt.xlabel("Name")
plt.ylabel("Attendance")
plt.show()

# %% [markdown]
# # Historigram for kills

# %%
plt.hist(df["kills"], bins=15, color='green', edgecolor='black')

plt.title("finding the average kills")
plt.plot()
plt.show()

# %%
avg_kills_everyone = df["kills"].mean()
print("The average kills for everyone is: ", round(avg_kills_everyone))
# Out:
# The average kills for everyone is:  44

# %% [markdown]
# # There top 5 kills

# %%
find_avg = df[df["name"] == "Dawnftb"]
#you can put anyname 
find_avg["kills"].mean()

number_sort = find_avg["kills"].sort_values(ascending=False)

plt.bar(find_avg.sort_values(ascending=False, by="kills")["date"], find_avg["kills"].sort_values(ascending=False), color='black')


        
plt.title(f"Kills by Date by {find_avg['name'].iloc[0]}")
plt.xticks(rotation=90)
plt.xlabel("Date")
plt.ylabel("Kills")
plt.show()

# %% [markdown]
# # There performance for the last 5 days
