# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # We read the data first

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#                  name  kills        date
# 0             jgwen19     70  2025-02-09
# 1             Dawnftb     34  2025-02-09
# 2          Hparso1524     36  2025-02-09
# 3    MarionnJames2307     61  2025-02-09
# 4      chickenkampong     47  2025-02-09
# ..                ...    ...         ...
# 211        spikey_001     57  2025-01-30
# 212      theDogeboiiz     42  2025-01-30
# 213        GGXDArusha     28  2025-01-30
# 214            acid_w    103  2025-01-30
# 215        camper8903     41  2025-01-30
#
# [216 rows x 3 columns]

# %% [markdown]
# # Top 10 attandence

# %%
df["name"].value_counts().nlargest(10).plot(kind='bar',colormap='viridis')
plt.title("Attendance by Name")
plt.xlabel("Name")
plt.ylabel("Attendance")
plt.show()

# %% [markdown]
# # There top 5 kills

# %%
find_avg = df[df["name"] == "Dawnftb"]
#you can put anyname not just gwen
find_avg["kills"].mean()

number_sort = find_avg["kills"].sort_values(ascending=False)

plt.bar(find_avg["date"], find_avg["kills"].sort_values(ascending=False), color='black')


        
plt.title(f"Kills by Date by {find_avg['name'].iloc[0]}")
plt.xticks(rotation=90)
plt.xlabel("Date")
plt.ylabel("Kills")
plt.show()
